# %% [markdown]
# ### Data Manipulation and Analysis with Pandas
#
# Data manipulation and analysis are keys tasks in any data science or data analyst project. Pandas provides a wide range of functions for data manipulation and analysis, making it esaier to clean, transform, and extract insights from data. In this lesson, we will cover various data manipulations and analysis techniques using Pandas.

# %%
import pandas as pd

df = pd.read_csv('example.csv')

## fetch the first 5 rows 

df.head(5)
# Out:
#     Name  Age  Number  Zip_code
# 0   Hola   12      89        45
# 1   Faaa   87       9         6
# 2    Alo    7       5         8
# 3  Acaaa    8       6         8
# 4   Hola   12      89        45

# %%
df.tail(5)
# Out:
#      Name  Age  Number  Zip_code
# 59  Acaaa    8       6         8
# 60   Hola   12      89        45
# 61   Faaa   87       9         6
# 62    Alo    7       5         8
# 63  Acaaa    8       6         8

# %%
df.describe()
# Out:
#              Age     Number   Zip_code
# count  64.000000  64.000000  64.000000
# mean   28.500000  27.250000  16.750000
# std    34.094174  35.963827  16.459667
# min     7.000000   5.000000   6.000000
# 25%     7.750000   5.750000   7.500000
# 50%    10.000000   7.500000   8.000000
# 75%    30.750000  29.000000  17.250000
# max    87.000000  89.000000  45.000000

# %%
df.dtypes
# Out:
# Name        object
# Age          int64
# Number       int64
# Zip_code     int64
# dtype: object

# %%
## Handling missing values
df.isnull().sum()
# Out:
# Name        0
# Age         0
# Number      0
# Zip_code    0
# dtype: int64

# %%
df_filled = df.fillna(0)

# %%
## filling missing vvalues with the mean of the column

df['Name']
# Out:
# 0      Hola
# 1      Faaa
# 2       Alo
# 3     Acaaa
# 4      Hola
#       ...
# 59    Acaaa
# 60     Hola
# 61     Faaa
# 62      Alo
# 63    Acaaa
# Name: Name, Length: 64, dtype: object

# %%
df['Age_fillNA'] = df['Age'].fillna(df['Age'].mean())
df
# Out:
#      Name  Age  Number  Zip_code  Age_fillNA
# 0    Hola   12      89        45          12
# 1    Faaa   87       9         6          87
# 2     Alo    7       5         8           7
# 3   Acaaa    8       6         8           8
# 4    Hola   12      89        45          12
# ..    ...  ...     ...       ...         ...
# 59  Acaaa    8       6         8           8
# 60   Hola   12      89        45          12
# 61   Faaa   87       9         6          87
# 62    Alo    7       5         8           7
# 63  Acaaa    8       6         8           8
#
# [64 rows x 5 columns]

# %%
df.dtypes
# Out:
# Name          object
# Age            int64
# Number         int64
# Zip_code       int64
# Age_fillNA     int64
# dtype: object

# %%
## Renaming columns

df = df.rename(columns={'Name':'Full_Name'})
df.head()
# Out:
#   Full_Name  Age  Number  Zip_code  Age_fillNA
# 0      Hola   12      89        45          12
# 1      Faaa   87       9         6          87
# 2       Alo    7       5         8           7
# 3     Acaaa    8       6         8           8
# 4      Hola   12      89        45          12

# %%
df['Value_new'] = df['Zip_code'].astype(float)
df.head()
# Out:
#   Full_Name  Age  Number  Zip_code  Age_fillNA  Value_new
# 0      Hola   12      89        45          12       45.0
# 1      Faaa   87       9         6          87        6.0
# 2       Alo    7       5         8           7        8.0
# 3     Acaaa    8       6         8           8        8.0
# 4      Hola   12      89        45          12       45.0

# %%
df['New Value'] = df['Zip_code'].apply(lambda x:x**2)
df['New Value'] = df['Zip_code'].apply(lambda x:x==2)
df
# Out:
#    Full_Name  Age  Number  Zip_code  Age_fillNA  Value_new  New Value
# 0       Hola   12      89        45          12       45.0       2025
# 1       Faaa   87       9         6          87        6.0         36
# 2        Alo    7       5         8           7        8.0         64
# 3      Acaaa    8       6         8           8        8.0         64
# 4       Hola   12      89        45          12       45.0       2025
# ..       ...  ...     ...       ...         ...        ...        ...
# 59     Acaaa    8       6         8           8        8.0         64
# 60      Hola   12      89        45          12       45.0       2025
# 61      Faaa   87       9         6          87        6.0         36
# 62       Alo    7       5         8           7        8.0         64
# 63     Acaaa    8       6         8           8        8.0         64
#
# [64 rows x 7 columns]

# %%
### Data aggregating and Grouping

grouped_mean=df.groupby('Full_Name')['Number'].mean()
print(grouped_mean)
# Out:
# Full_Name
# Acaaa     6.0
# Alo       5.0
# Faaa      9.0
# Hola     89.0
# Name: Number, dtype: float64

# %%
grouped_two = df.groupby(['Full_Name','Zip_code'])['Number'].sum()
grouped_two
# Out:
# Full_Name  Zip_code
# Acaaa      8             96
# Alo        8             80
# Faaa       6            144
# Hola       45          1424
# Name: Number, dtype: int64

# %%
grouped_two = df.groupby(['Full_Name','Zip_code'])['Number'].mean()
grouped_two
# Out:
# Full_Name  Zip_code
# Acaaa      8            6.0
# Alo        8            5.0
# Faaa       6            9.0
# Hola       45          89.0
# Name: Number, dtype: float64

# %%
### aggregate multiple functions

grouped_agg = df.groupby('Full_Name')['Number'].agg(['mean','sum','count'])
grouped_agg
# Out:
#            mean   sum  count
# Full_Name
# Acaaa       6.0    96     16
# Alo         5.0    80     16
# Faaa        9.0   144     16
# Hola       89.0  1424     16
